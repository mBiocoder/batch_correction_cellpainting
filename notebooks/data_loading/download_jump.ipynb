# %%
# !pip install anndata

# %%
# !pip install s3fs

# %%
import io
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import anndata as ad

# %%
# %load_ext autoreload
# %autoreload 2
from google.colab import drive
import os
gdrive_path='/content/gdrive/MyDrive/Masterpraktikum'
drive.mount('/content/gdrive', force_remount=True)
os.chdir(gdrive_path)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Loading profiles from the JUMP Cell Painting Datasets
#
# *adapted from: https://github.com/jump-cellpainting/datasets/blob/main/sample_notebook.ipynb*

# %% [markdown]
# ### Which data will we be using?

# %% [markdown]
# - All Target2 plates
# - 8 positive controls and DMSO of the COMPOUND plates

# %% [markdown]
# ### Load metadata
#
# The following files contain the metadata information for the entire dataset.
# The schema is [here](metadata/README.md).

# %%
GIT_CLONE_DIR = "/content/gdrive/MyDrive/Masterpraktikum/Blockteil/datasets/"

# %%
plates = pd.read_csv(os.path.join(GIT_CLONE_DIR, "metadata/plate.csv.gz"))
wells = pd.read_csv(os.path.join(GIT_CLONE_DIR, "metadata/well.csv.gz"))
compound = pd.read_csv(os.path.join(GIT_CLONE_DIR, "metadata/compound.csv.gz"))

# %%
#tsv file obtained from https://github.com/jump-cellpainting/JUMP-Target/blob/master/JUMP-Target-2_compound_metadata.tsv
compound_metadata = pd.read_csv("/content/gdrive/MyDrive/Masterpraktikum/Blockteil/JUMP-Target-2_compound_metadata.tsv", delimiter = "\t")
compound_metadata.head()
# Out:
#              broad_sample                     InChIKey      pert_iname  \
# 0  BRD-K09338665-001-07-1  KBPLFHHGFOOTCA-UHFFFAOYSA-N       1-octanol
# 1  BRD-K48278478-001-01-2  LOUPRKONTZGTKE-AFHBHXEDSA-N         quinine
# 2  BRD-A85242401-001-12-3  KRGQEOSDQHTZMX-IGCYCDGOSA-N   ascorbic-acid
# 3  BRD-K93632104-001-17-2  YGSDEFSMJLZEOE-UHFFFAOYSA-N  salicylic-acid
# 4  BRD-K57313110-001-06-8  ODHCTXKNWHHXJC-VKHMYHEASA-N    pidolic-acid
#
#    pubchem_cid  target pert_type control_type  \
# 0        957.0    GJB4       trt          NaN
# 1      94175.0   KCNN4       trt          NaN
# 2    9888239.0    P3H1       trt          NaN
# 3  118212070.0  AKR1C1       trt          NaN
# 4       7405.0   VEGFA       trt          NaN
#
#                                               smiles
# 0                                          CCCCCCCCO
# 1  COc1ccc2nccc([C@@H](O)[C@H]3C[C@@H]4CC[N@]3C[C...
# 2                     OC[C@H](O)[C@H]1OC(=O)C(=O)C1O
# 3                                    OC(=O)c1ccccc1O
# 4                             OC(=O)[C@@H]1CCC(=O)N1

# %% [markdown]
# ### Subset on plates and wells of interest

# %% [markdown]
# **1. Subset on the target2 plates:**

# %%
sample_target2 = plates.query("Metadata_PlateType == 'TARGET2'")
sample_target2.head()
# Out:
#     Metadata_Source               Metadata_Batch     Metadata_Plate  \
# 161       source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 180       source_10  2021_08_09_U2OS_48_hr_run13  Dest210727-153003
# 195       source_10  2021_08_12_U2OS_48_hr_run15  Dest210803-153958
# 213       source_10  2021_08_17_U2OS_48_hr_run16  Dest210809-134534
# 231       source_10  2021_08_20_U2OS_48_hr_run17  Dest210810-173723
#
#     Metadata_PlateType
# 161            TARGET2
# 180            TARGET2
# 195            TARGET2
# 213            TARGET2
# 231            TARGET2

# %% [markdown]
# **2. Subset on the 8 poscons and the DMSO of the COMPOUND plates.** <br>
# To do so, we need the JCP2022 IDs of the poscons and the DMSO. In the following, we obtain the JCP2022 IDs of the 8 positive controls from the POSCON8 plates. THE JCP2022 ID of the DMSO from a metadata file: https://github.com/jump-cellpainting/JUMP-Target/blob/master/JUMP-Target-2_compound_metadata.tsv

# %%
poscon8_plates = plates.query("Metadata_PlateType == 'POSCON8'")
plates_wells = pd.merge(poscon8_plates, wells, on = ["Metadata_Plate", "Metadata_Source"])
# get IDs of the 8 positive controls:
poscon8_ids = plates_wells.Metadata_JCP2022.unique()
poscon8_ids
# Out:
# array(['JCP2022_085227', 'JCP2022_037716', 'JCP2022_025848',
#        'JCP2022_046054', 'JCP2022_035095', 'JCP2022_064022',
#        'JCP2022_050797', 'JCP2022_012818'], dtype=object)

# %%
#DMSO:
lnchikey_dmso = compound_metadata.query("pert_iname == 'DMSO'")["InChIKey"]
lnchikey_dmso
# get JCP_2022 ID from metadata/compound.tsv
dmso_key = compound[compound['Metadata_InChIKey'].isin(lnchikey_dmso)]["Metadata_JCP2022"].unique()

# %%
poscon_negcon_ids = np.concatenate([dmso_key,poscon8_ids])
poscon_negcon_ids
# Out:
# array(['JCP2022_033924', 'JCP2022_085227', 'JCP2022_037716',
#        'JCP2022_025848', 'JCP2022_046054', 'JCP2022_035095',
#        'JCP2022_064022', 'JCP2022_050797', 'JCP2022_012818'], dtype=object)

# %%
# subset compound plates on those wells:
compound_plates = plates.query("Metadata_PlateType == 'COMPOUND'")
compound_wells = pd.merge(compound_plates, wells, on = ["Metadata_Plate", "Metadata_Source"])
sample_pc_nc = compound_wells[compound_wells['Metadata_JCP2022'].isin(poscon_negcon_ids)]

# %%
sample_pc_nc.head()
# Out:
#    Metadata_Source   Metadata_Batch Metadata_Plate Metadata_PlateType  \
# 0         source_1  Batch1_20221004       UL001641           COMPOUND
# 1         source_1  Batch1_20221004       UL001641           COMPOUND
# 2         source_1  Batch1_20221004       UL001641           COMPOUND
# 43        source_1  Batch1_20221004       UL001641           COMPOUND
# 44        source_1  Batch1_20221004       UL001641           COMPOUND
#
#    Metadata_Well Metadata_JCP2022
# 0            A02   JCP2022_033924
# 1            A03   JCP2022_085227
# 2            A04   JCP2022_033924
# 43           A45   JCP2022_033924
# 44           A46   JCP2022_085227

# %% [markdown]
# ### Loading profiles
# Now let's load the profiles from these plates and wells.
#
# Setting `columns = None` below will load all of the features, n_features = 4762

# %%
profile_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/profiles/"
    "{Metadata_Batch}/{Metadata_Plate}/{Metadata_Plate}.parquet"
)

# %% [markdown]
# **1. Load Target2 plates**

# %%
sample = sample_target2
sample

# %%
dframes_target2 = []
columns = None
for _, row in tqdm(sample.iterrows(), total=len(sample)):
    s3_path = profile_formatter.format(**row.to_dict())
    dframes_target2.append(
        pd.read_parquet(s3_path, storage_options={"anon": True}, columns=columns)
    )
dframes_target2 = pd.concat(dframes_target2)
dframes_target2
# Out:
#   0%|          | 0/141 [00:00<?, ?it/s]
#      Metadata_Source     Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0          source_10  Dest210726-160150           A01                3846.4
# 1          source_10  Dest210726-160150           A02                3484.2
# 2          source_10  Dest210726-160150           A03                3281.9
# 3          source_10  Dest210726-160150           A04                3476.5
# 4          source_10  Dest210726-160150           A05                3592.1
# ...              ...                ...           ...                   ...
# 1531        source_9         GR00004409           Z44                2501.1
# 1532        source_9         GR00004409           Z45                2497.0
# 1533        source_9         GR00004409           Z46                2470.0
# 1534        source_9         GR00004409           Z47                2725.4
# 1535        source_9         GR00004409           Z48                2811.6
#
#       Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                              8135.6                                594.88
# 1                              7088.1                                541.40
# 2                              6740.3                                540.91
# 3                              7233.5                                554.90
# 4                              7581.8                                565.46
# ...                               ...                                   ...
# 1531                           4571.1                                560.30
# 1532                           4529.4                                555.90
# 1533                           4479.2                                548.36
# 1534                           5025.1                                553.86
# 1535                           5146.8                                528.91
#
#       Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                   544.30
# 1                                   539.61
# 2                                   564.09
# 3                                   491.65
# 4                                   555.42
# ...                                    ...
# 1531                                560.26
# 1532                                563.43
# 1533                                578.95
# 1534                                565.84
# 1535                                577.75
#
#       Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                   506.29
# 1                                   458.50
# 2                                   458.88
# 3                                   472.11
# 4                                   480.46
# ...                                    ...
# 1531                                493.83
# 1532                                491.44
# 1533                                482.96
# 1534                                485.54
# 1535                                458.83
#
#       Cells_AreaShape_BoundingBoxMinimum_Y  Cells_AreaShape_Center_X  ...  \
# 0                                   454.05                    550.31  ...
# 1                                   455.57                    499.72  ...
# 2                                   483.44                    498.92  ...
# 3                                   406.53                    512.92  ...
# 4                                   468.08                    522.43  ...
# ...                                    ...                       ...  ...
# 1531                                493.32                    526.64  ...
# 1532                                495.61                    523.31  ...
# 1533                                512.79                    515.18  ...
# 1534                                495.00                    519.22  ...
# 1535                                507.01                    493.26  ...
#
#       Nuclei_Texture_Variance_RNA_10_02_256  \
# 0                                    52.879
# 1                                    62.107
# 2                                    54.887
# 3                                    56.545
# 4                                    64.136
# ...                                     ...
# 1531                                 54.051
# 1532                                 52.398
# 1533                                 60.019
# 1534                                 52.872
# 1535                                 49.069
#
#       Nuclei_Texture_Variance_RNA_10_03_256  \
# 0                                    49.352
# 1                                    55.949
# 2                                    50.217
# 3                                    52.062
# 4                                    58.298
# ...                                     ...
# 1531                                 53.101
# 1532                                 50.418
# 1533                                 58.125
# 1534                                 51.857
# 1535                                 48.489
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                                   50.861
# 1                                   59.508
# 2                                   52.887
# 3                                   56.238
# 4                                   62.002
# ...                                    ...
# 1531                                51.344
# 1532                                49.035
# 1533                                56.818
# 1534                                49.610
# 1535                                46.207
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                   51.543
# 1                                   60.461
# 2                                   53.876
# 3                                   57.078
# 4                                   63.093
# ...                                    ...
# 1531                                51.742
# 1532                                49.288
# 1533                                57.189
# 1534                                49.757
# 1535                                46.536
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                   50.538
# 1                                   59.221
# 2                                   52.707
# 3                                   55.913
# 4                                   61.794
# ...                                    ...
# 1531                                51.299
# 1532                                49.087
# 1533                                56.923
# 1534                                49.552
# 1535                                46.245
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                   51.884
# 1                                   60.675
# 2                                   53.984
# 3                                   57.400
# 4                                   63.153
# ...                                    ...
# 1531                                51.507
# 1532                                49.531
# 1533                                57.286
# 1534                                50.035
# 1535                                46.579
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                   52.263
# 1                                   61.428
# 2                                   54.283
# 3                                   57.872
# 4                                   63.637
# ...                                    ...
# 1531                                51.875
# 1532                                49.877
# 1533                                57.917
# 1534                                50.196
# 1535                                46.959
#
#       Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                   52.625
# 1                                   62.315
# 2                                   55.613
# 3                                   58.614
# 4                                   64.359
# ...                                    ...
# 1531                                53.164
# 1532                                51.324
# 1533                                59.310
# 1534                                51.243
# 1535                                48.079
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                   52.144
# 1                                   61.100
# 2                                   54.511
# 3                                   57.834
# 4                                   63.523
# ...                                    ...
# 1531                                51.923
# 1532                                49.960
# 1533                                57.726
# 1534                                50.180
# 1535                                46.756
#
#       Nuclei_Texture_Variance_RNA_5_03_256
# 0                                   53.302
# 1                                   62.480
# 2                                   55.356
# 3                                   58.898
# 4                                   64.394
# ...                                    ...
# 1531                                52.834
# 1532                                51.313
# 1533                                59.307
# 1534                                51.654
# 1535                                48.111
#
# [64464 rows x 4765 columns]

# %% [markdown]
# **2. Load positive and negative controls**

# %%
sample = sample_pc_nc#.iloc[[3]]
sample

# %%
sample_plates = sample.groupby(['Metadata_Source','Metadata_Batch', "Metadata_Plate"]).count().reset_index()

# %%
columns = None
dfs_pcs_ncs = []
for _, row in tqdm(sample_plates.iterrows(), total=len(sample_plates)):
    #pull plate
    s3_path = profile_formatter.format(**row.to_dict())
    plate = pd.read_parquet(s3_path, storage_options={"anon": True}, columns=columns)
    #subset on poscon and negcon wells
    wells_interest = sample_pc_nc[sample_pc_nc["Metadata_Plate"] == row["Metadata_Plate"]]["Metadata_Well"]
    #append to dataframe
    dfs_pcs_ncs.append(
        plate[plate["Metadata_Well"].isin(wells_interest)]
    )
dfs_pcs_ncs = pd.concat(dfs_pcs_ncs)
# Out:
#   0%|          | 0/1729 [00:00<?, ?it/s]

# %%
dfs_pcs_ncs.to_csv("/content/gdrive/MyDrive/Masterpraktikum/Blockteil/PCs_DMSO.csv")

# %% [markdown]
# ### Create AnnData

# %% [markdown]
# **Target2**

# %%
# get .X
X = np.array(dframes_target2.iloc[:,3:])
# get obs
obs = dframes_target2.iloc[:,:3]
# create anndata
adata_target2 = ad.AnnData(X=X, obs=obs)
adata_target2
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 64464 × 4762
#     obs: 'Metadata_Source', 'Metadata_Plate', 'Metadata_Well'

# %% [markdown]
# Save anndata:

# %%
adata_target2.write("/content/gdrive/MyDrive/Masterpraktikum/Blockteil/target2.h5ad")

# %% [markdown]
# **Poscon8 and DMSO**

# %% [markdown]
# ### Add additional metadata

# %% [markdown]
# **Target2**

# %%
adata_target2 = ad.read_h5ad("/content/gdrive/MyDrive/Masterpraktikum/Blockteil/target2.h5ad")
adata_target2
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 64464 × 4762
#     obs: 'Metadata_Source', 'Metadata_Plate', 'Metadata_Well'

# %%
metadata = compound.merge(wells, on="Metadata_JCP2022")
adata_target2.obs = pd.merge(adata_target2.obs, metadata, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"])
adata_target2.obs.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:788: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)
#   Metadata_Source     Metadata_Plate Metadata_Well Metadata_JCP2022  \
# 0       source_10  Dest210726-160150           A01   JCP2022_043547
# 1       source_10  Dest210726-160150           A02   JCP2022_050797
# 2       source_10  Dest210726-160150           A03   JCP2022_050997
# 3       source_10  Dest210726-160150           A04   JCP2022_108326
# 4       source_10  Dest210726-160150           A05   JCP2022_033924
#
#              Metadata_InChIKey  \
# 0  KBPLFHHGFOOTCA-UHFFFAOYSA-N
# 1  LOUPRKONTZGTKE-UHFFFAOYSA-N
# 2  LPYXWGMUVRGUOY-UHFFFAOYSA-N
# 3  YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 4  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
#
#                                       Metadata_InChI
# 0   InChI=1S/C8H18O/c1-2-3-4-5-6-7-8-9/h9H,2-8H2,1H3
# 1  InChI=1S/C20H24N2O2/c1-3-13-12-22-9-7-14(13)10...
# 2  InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/...
# 3  InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...
# 4                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3

# %% [markdown]
# Let's add metadata of the microscopes:

# %%
microscope_config = pd.read_csv(os.path.join(GIT_CLONE_DIR, "metadata/microscope_config.csv"))
microscope_config['Metadata_Source'] = 'source_' + microscope_config['Metadata_Source'].astype(str)
microscope_config.head()
# Out:
#   Metadata_Source Metadata_Microscope_Name Metadata_Widefield_vs_Confocal  \
# 0        source_1             Opera Phenix                      Widefield
# 1        source_2                   CV8000                       Confocal
# 2        source_3             Opera Phenix                      Widefield
# 3        source_4             Opera Phenix                      Widefield
# 4        source_5                   CV8000                       Confocal
#
#   Metadata_Excitation_Type  Metadata_Objective_NA  \
# 0                    Laser                   1.00
# 1                    Laser                   1.00
# 2                    Laser                   1.00
# 3                    Laser                   1.00
# 4                    Laser                   0.75
#
#    Metadata_N_Brightfield_Planes_Min  Metadata_N_Brightfield_Planes_Max  \
# 0                                  1                                  1
# 1                                  3                                  3
# 2                                  0                                  3
# 3                                  3                                  3
# 4                                  3                                  3
#
#    Metadata_Distance_Between_Z_Microns  Metadata_Sites_Per_Well  \
# 0                                  NaN                        4
# 1                                  8.0                        6
# 2                                  5.0                        9
# 3                                  5.0                        9
# 4                                  5.0                        9
#
#   Metadata_Filter_Configuration
# 0                             H
# 1                             A
# 2                             B
# 3                             B
# 4                             C

# %%
adata_target2.obs = pd.merge(adata_target2.obs, microscope_config[["Metadata_Source", "Metadata_Microscope_Name"
, "Metadata_Widefield_vs_Confocal", "Metadata_Excitation_Type", "Metadata_Sites_Per_Well"]],
         on = "Metadata_Source")
adata_target2.obs.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:788: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)
#   Metadata_Source     Metadata_Plate Metadata_Well Metadata_JCP2022  \
# 0       source_10  Dest210726-160150           A01   JCP2022_043547
# 1       source_10  Dest210726-160150           A02   JCP2022_050797
# 2       source_10  Dest210726-160150           A03   JCP2022_050997
# 3       source_10  Dest210726-160150           A04   JCP2022_108326
# 4       source_10  Dest210726-160150           A05   JCP2022_033924
#
#              Metadata_InChIKey  \
# 0  KBPLFHHGFOOTCA-UHFFFAOYSA-N
# 1  LOUPRKONTZGTKE-UHFFFAOYSA-N
# 2  LPYXWGMUVRGUOY-UHFFFAOYSA-N
# 3  YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 4  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
#
#                                       Metadata_InChI Metadata_Microscope_Name  \
# 0   InChI=1S/C8H18O/c1-2-3-4-5-6-7-8-9/h9H,2-8H2,1H3                   CV8000
# 1  InChI=1S/C20H24N2O2/c1-3-13-12-22-9-7-14(13)10...                   CV8000
# 2  InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/...                   CV8000
# 3  InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...                   CV8000
# 4                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3                   CV8000
#
#   Metadata_Widefield_vs_Confocal Metadata_Excitation_Type  \
# 0                       Confocal                    Laser
# 1                       Confocal                    Laser
# 2                       Confocal                    Laser
# 3                       Confocal                    Laser
# 4                       Confocal                    Laser
#
#    Metadata_Sites_Per_Well
# 0                        6
# 1                        6
# 2                        6
# 3                        6
# 4                        6

# %% [markdown]
# Let's try to add some information about the pertubations and target genes:

# %%
compound_metadata.head()
# Out:
#              broad_sample                     InChIKey      pert_iname  \
# 0  BRD-K09338665-001-07-1  KBPLFHHGFOOTCA-UHFFFAOYSA-N       1-octanol
# 1  BRD-K48278478-001-01-2  LOUPRKONTZGTKE-AFHBHXEDSA-N         quinine
# 2  BRD-A85242401-001-12-3  KRGQEOSDQHTZMX-IGCYCDGOSA-N   ascorbic-acid
# 3  BRD-K93632104-001-17-2  YGSDEFSMJLZEOE-UHFFFAOYSA-N  salicylic-acid
# 4  BRD-K57313110-001-06-8  ODHCTXKNWHHXJC-VKHMYHEASA-N    pidolic-acid
#
#    pubchem_cid  target pert_type control_type  \
# 0        957.0    GJB4       trt          NaN
# 1      94175.0   KCNN4       trt          NaN
# 2    9888239.0    P3H1       trt          NaN
# 3  118212070.0  AKR1C1       trt          NaN
# 4       7405.0   VEGFA       trt          NaN
#
#                                               smiles
# 0                                          CCCCCCCCO
# 1  COc1ccc2nccc([C@@H](O)[C@H]3C[C@@H]4CC[N@]3C[C...
# 2                     OC[C@H](O)[C@H]1OC(=O)C(=O)C1O
# 3                                    OC(=O)c1ccccc1O
# 4                             OC(=O)[C@@H]1CCC(=O)N1

# %%
adata_target2.obs = pd.merge(adata_target2.obs, compound_metadata, left_on = "Metadata_InChIKey", right_on = "InChIKey", how = "left")
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:788: UserWarning:
# AnnData expects .obs.index to contain strings, but got values like:
#     [0, 1, 2, 3, 4]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
adata_target2
# Out:
# AnnData object with n_obs × n_vars = 64464 × 4762
#     obs: 'Metadata_Source', 'Metadata_Plate', 'Metadata_Well', 'Metadata_JCP2022', 'Metadata_InChIKey', 'Metadata_InChI', 'Metadata_Microscope_Name', 'Metadata_Widefield_vs_Confocal', 'Metadata_Excitation_Type', 'Metadata_Sites_Per_Well', 'broad_sample', 'InChIKey', 'pert_iname', 'pubchem_cid', 'target', 'pert_type', 'control_type', 'smiles'

# %% [markdown]
# For how many pertubations is a pert_type not available?

# %%
len(adata_target2.obs[adata_target2.obs["pert_type"].isna()]["Metadata_InChIKey"].unique())
# Out:
# 120

# %% [markdown]
# For how many is a pert_type available?

# %%
len(adata_target2.obs[~(adata_target2.obs["pert_type"].isna())]["Metadata_InChIKey"].unique())
# Out:
# 182

# %% [markdown]
# Let's save the anndata:

# %%
adata_target2.write("/content/gdrive/MyDrive/Masterpraktikum/Blockteil/target2_md.h5ad")
